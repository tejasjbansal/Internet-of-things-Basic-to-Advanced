# %% [markdown]
# # AIoT Lab 6 — Computer Vision for Smart Manufacturing
#
# Build an AI-powered visual inspection system using Deep Learning.

# %% [markdown]
# ## Step 1 — Install Required Libraries

# %%
# !pip install tensorflow matplotlib numpy pandas scikit-learn

# %% [markdown]
# ## Step 2 — Import Required Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Step 3 — Load Image Dataset

# %%
(X_train,y_train),(X_test,y_test)=fashion_mnist.load_data()
print(X_train.shape)

# %% [markdown]
# ## Step 4 — Visualize Sample Images

# %%
plt.imshow(X_train[0],cmap='gray')
plt.show()

# %% [markdown]
# ## Step 5 — Preprocess Images

# %%
X_train=X_train.astype('float32')/255
X_test=X_test.astype('float32')/255
X_train=X_train.reshape(-1,28,28,1)
X_test=X_test.reshape(-1,28,28,1)
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %% [markdown]
# ## Step 6 — Build CNN Model

# %%
model=Sequential([
Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)),
MaxPooling2D((2,2)),
Flatten(),
Dense(128,activation='relu'),
Dense(10,activation='softmax')
])
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()

# %% [markdown]
# ## Step 7 — Train Deep Learning Model

# %%
model.fit(X_train,y_train,epochs=3,batch_size=128,validation_split=0.2)

# %% [markdown]
# ## Step 8 — Evaluate Model

# %%
loss,acc=model.evaluate(X_test,y_test)
print(acc)

# %% [markdown]
# ## Step 9 — Perform Image Classification

# %%
pred=model.predict(X_test[:5])
print(np.argmax(pred,axis=1))

# %% [markdown]
# ## Step 10 — Simulate Real-Time Inspection

# %%
sample=X_test[0].reshape(1,28,28,1)
print(np.argmax(model.predict(sample)))

# %% [markdown]
# ## Step 11 — Generate Quality Alert

# %%
print('Quality Inspection Completed')

# %% [markdown]
# ## Lab Summary
# Deep Learning, CNNs, Image Classification, Visual Inspection, Quality Control Alerts
